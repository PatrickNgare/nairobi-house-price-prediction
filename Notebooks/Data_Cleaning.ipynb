# %%
import pandas as pd

# %%
df=pd.read_csv("all_listings_demo.csv")
df.head()
# Out:
#          source listing_id                           title       location  \
# 0  DiamondTrust      A0000  3BR Apartment in Ongata Rongai  Ongata Rongai
# 1  BuyRentKenya      B0001          1BR Townhouse in Runda          Runda
# 2  BuyRentKenya      C0002         3BR Villa in Kileleshwa     Kileleshwa
# 3  BuyRentKenya      D0003         3BR House in Kileleshwa     Kileleshwa
# 4  BuyRentKenya      E0004          3BR Townhouse in Runda          Runda
#
#   property_type  bedrooms  bathrooms  size_sqft  price_kes        amenities  \
# 0     Apartment         3          2       1173   21850876              NaN
# 1     Townhouse         1          1       1011   68839086              NaN
# 2         Villa         3          3       2497   38227887              NaN
# 3         House         3          3       2238   29325823        lift|pool
# 4     Townhouse         3          2       1646  114841361  pool|gym|garden
#
#                       listing_url scrape_date
# ...

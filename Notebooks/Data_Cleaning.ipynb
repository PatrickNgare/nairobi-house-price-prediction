# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
buyrent=pd.read_csv("all_listings_raw.csv")

buyrent.head()
# Out:
#          source  listing_id     title location property_type  bedrooms  \
# 0  BuyRentKenya  89a2c0cd86  Property  Nairobi       Unknown       NaN
# 1  BuyRentKenya  354347e742  Property  Nairobi       Unknown       NaN
# 2  BuyRentKenya  7bdc279289  Property  Nairobi       Unknown       NaN
# 3  BuyRentKenya  9adf7c7f07  Property  Nairobi       Unknown       NaN
# 4  BuyRentKenya  bc973fca3f  Property  Nairobi       Unknown       NaN
#
#    bathrooms  size_sqft  price_kes  amenities listing_url scrape_date
# 0        NaN        NaN   25300000        NaN         NaN  2026-02-19
# 1        NaN        NaN   13700000        NaN         NaN  2026-02-19
# 2        NaN        NaN    6100000        NaN         NaN  2026-02-19
# 3        NaN        NaN   10300000        NaN         NaN  2026-02-19
# 4        NaN        NaN   16700000        NaN         NaN  2026-02-19

# %%
buyrent.isnull().sum()
# Out:
# source             0
# listing_id         0
# title              0
# location           0
# property_type      0
# bedrooms         251
# bathrooms        251
# size_sqft        251
# price_kes          0
# amenities        251
# listing_url       12
# scrape_date        0
# dtype: int64

# %%
dfrentpro=pd.read_csv("listings_20260219_103449.csv")

# %%
dfrentpro.head()
# Out:
#          source  listing_id     title location property_type  bedrooms  \
# 0  BuyRentKenya  0a2dad59e9  Property  Nairobi       Unknown       NaN
# 1  BuyRentKenya  0a2dad59e9  Property  Nairobi       Unknown       NaN
# 2  BuyRentKenya  b635201147  Property  Nairobi       Unknown       NaN
# 3  BuyRentKenya  b635201147  Property  Nairobi       Unknown       NaN
# 4  BuyRentKenya  23dc7b9655  Property  Nairobi       Unknown       NaN
#
#    bathrooms  size_sqft  price_kes  amenities listing_url scrape_date
# 0        NaN        NaN   17500000        NaN         NaN  2026-02-19
# 1        NaN        NaN   17500000        NaN         NaN  2026-02-19
# 2        NaN        NaN    5800000        NaN         NaN  2026-02-19
# 3        NaN        NaN    5800000        NaN         NaN  2026-02-19
# 4        NaN        NaN    6000000        NaN         NaN  2026-02-19
